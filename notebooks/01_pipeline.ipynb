# %% [markdown]
# # Interpretability Analysis of CNNs and Vision Transformers under Image Corruptions

# %%
import sys, os

# 1. Setup Environment (handles both Colab and Local Execution)
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    
    # We want everything inside Drive so checkpoints persist automatically
    REPO_PATH = '/content/drive/MyDrive/attention-vit'
    
    if not os.path.exists(REPO_PATH):
        print("Repository not found in Drive. Cloning now...")
        # %cd /content/drive/MyDrive
        # !git clone https://github.com/M-DEV-1/attention-ViT.git attention-vit
    
    # %cd {REPO_PATH}
    print("Pulling latest changes...")
    # !git pull
else:
    # If running locally from the notebooks/ directory, move to the root
    if os.path.basename(os.getcwd()) == 'notebooks':
        # %cd ..
    print(f"Executing from: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/attention-vit
# Pulling latest changes...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 12 (delta 7), reused 10 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 2.88 KiB | 1024 bytes/s, done.
# From https://github.com/M-DEV-1/attention-ViT
#    7095054..381cbb2  master     -> origin/master
# Updating 7095054..381cbb2
# Fast-forward
#  scripts/run.py                | 31 ++++++++++--------------
#  src/core/evaluate.py          | 35 ++++++++++++++++++++++++++-
#  src/utils/interpretability.py | 56 +++++++++++++++++++++++++++++++++++++++++++
#  3 files changed, 102 insertions(+), 20 deletions(-)

# %%
# %pip install -r requirements.txt

# %%
# 2. Verify config and imports work natively
import src.config as config
print(f"Classes: {config.NUM_CLASSES}, Epochs: {config.NUM_EPOCHS}")
# Out:
# Classes: 100, Epochs: 10

# %%
# !python scripts/run.py --mode all --no-resume
# Out:
# 2026-04-16 02:02:15,874 - INFO - Using GPU: Tesla T4 (CUDA: 12.8)
# 2026-04-16 02:02:31,596 - INFO - === Processing Model: resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 134MB/s]
# 2026-04-16 02:02:33,091 - INFO - Starting Training for 10 epochs...
# 2026-04-16 02:02:33,093 - INFO - Found checkpoint at /content/drive/MyDrive/attention-vit/checkpoints/resnet50_latest.pth. Resuming...
# 2026-04-16 02:02:40,326 - INFO - Starting Robustness Evaluation...
# 2026-04-16 02:02:40,327 - INFO - Found checkpoint at /content/drive/MyDrive/attention-vit/checkpoints/resnet50_latest.pth. Resuming...
# 2026-04-16 02:02:41,686 - INFO - Evaluating resnet50 on clean (Severity: 1)
# 2026-04-16 02:03:15,165 - INFO - Accuracy: 43.06%, Avg Conf: 0.4817
# 2026-04-16 02:03:15,165 - INFO - Evaluating resnet50 on blur (Severity: 1)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob

figures = glob.glob('results/figures/*.png')
if not figures:
    print("No figures found. Make sure to run the interpretability step first!")
for fig in figures:
    plt.figure(figsize=(10, 5))
    img = mpimg.imread(fig)
    plt.imshow(img)
    plt.axis('off')
    plt.title(fig.split('/')[-1])
    plt.show()
